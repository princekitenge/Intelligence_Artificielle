# %% [markdown]
# # 1. Importation des Librairies

# %%
# importer les Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Pour installer Tensorflow : pip install tensorflow  / conda install tensorflow
# Pour installer keras : pip install keras / conda install keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Charger les donnees

# %%
# # Charger les donnees
data = pd.read_csv('Data/DDoS_dataset.csv')
data.head()
# Out:
#       dt  switch       src       dst  pktcount  bytecount  dur   dur_nsec  \
# 0  11425       1  10.0.0.1  10.0.0.8     45304   48294064  100  716000000
# 1  11605       1  10.0.0.1  10.0.0.8    126395  134737070  280  734000000
# 2  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 3  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 4  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
#
#         tot_dur  flows  ...  pktrate  Pairflow  Protocol  port_no   tx_bytes  \
# 0  1.010000e+11      3  ...      451         0       UDP        3  143928631
# 1  2.810000e+11      2  ...      451         0       UDP        4       3842
# 2  2.010000e+11      3  ...      451         0       UDP        1       3795
# 3  2.010000e+11      3  ...      451         0       UDP        2       3688
# 4  2.010000e+11      3  ...      451         0       UDP        3       3413
#
#   rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0     3917        0      0.0       0.0      0
# 1     3520        0      0.0       0.0      0
# 2     1242        0      0.0       0.0      0
# 3     1492        0      0.0       0.0      0
# 4     3665        0      0.0       0.0      0
#
# [5 rows x 23 columns]

# %% [markdown]
# # Étape 3 : Analyse de données

# %%
# Étape 3 : Analyse de données
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104345 entries, 0 to 104344
# Data columns (total 23 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   dt           104345 non-null  int64
#  1   switch       104345 non-null  int64
#  2   src          104345 non-null  object
#  3   dst          104345 non-null  object
#  4   pktcount     104345 non-null  int64
#  5   bytecount    104345 non-null  int64
#  6   dur          104345 non-null  int64
#  7   dur_nsec     104345 non-null  int64
#  8   tot_dur      104345 non-null  float64
#  9   flows        104345 non-null  int64
#  10  packetins    104345 non-null  int64
#  11  pktperflow   104345 non-null  int64
#  12  byteperflow  104345 non-null  int64
#  13  pktrate      104345 non-null  int64
#  14  Pairflow     104345 non-null  int64
#  15  Protocol     104345 non-null  object
#  16  port_no      104345 non-null  int64
#  17  tx_bytes     104345 non-null  int64
#  18  rx_bytes     104345 non-null  int64
#  19  tx_kbps      104345 non-null  int64
#  20  rx_kbps      103839 non-null  float64
#  21  tot_kbps     103839 non-null  float64
#  22  label        104345 non-null  int64
# dtypes: float64(3), int64(17), object(3)
# memory usage: 18.3+ MB

# %%
data['src'].unique()
# Out:
# array(['10.0.0.1', '10.0.0.2', '10.0.0.4', '10.0.0.10', '10.0.0.3',
#        '10.0.0.5', '10.0.0.13', '10.0.0.6', '10.0.0.20', '10.0.0.11',
#        '10.0.0.12', '10.0.0.18', '10.0.0.8', '10.0.0.7', '10.0.0.9',
#        '10.0.0.14', '10.0.0.15', '10.0.0.16', '10.0.0.17'], dtype=object)

# %%
data['dst'].unique()
# Out:
# array(['10.0.0.8', '10.0.0.7', '10.0.0.3', '10.0.0.5', '10.0.0.10',
#        '10.0.0.13', '10.0.0.1', '10.0.0.11', '10.0.0.2', '10.0.0.4',
#        '10.0.0.9', '10.0.0.6', '10.0.0.14', '10.0.0.15', '10.0.0.12',
#        '10.0.0.16', '10.0.0.17', '10.0.0.18'], dtype=object)

# %%
data['Protocol'].unique()
# Out:
# array(['UDP', 'TCP', 'ICMP'], dtype=object)

# %%
data.drop(columns='src', inplace=True, axis=1)
data.drop(columns='dst', inplace=True, axis=1)
data.head()
# Out:
#       dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  flows  \
# 0  11425       1     45304   48294064  100  716000000  1.010000e+11      3
# 1  11605       1    126395  134737070  280  734000000  2.810000e+11      2
# 2  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 3  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 4  11425       1     90333   96294978  200  744000000  2.010000e+11      3
#
#    packetins  pktperflow  ...  pktrate  Pairflow  Protocol port_no   tx_bytes  \
# 0       1943       13535  ...      451         0       UDP       3  143928631
# 1       1943       13531  ...      451         0       UDP       4       3842
# 2       1943       13534  ...      451         0       UDP       1       3795
# 3       1943       13534  ...      451         0       UDP       2       3688
# 4       1943       13534  ...      451         0       UDP       3       3413
#
#    rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0      3917        0      0.0       0.0      0
# 1      3520        0      0.0       0.0      0
# 2      1242        0      0.0       0.0      0
# 3      1492        0      0.0       0.0      0
# 4      3665        0      0.0       0.0      0
#
# [5 rows x 21 columns]

# %% [markdown]
# # Étape 4 : Prétraitement des données

# %%
encoder = LabelEncoder()

# %%
data['Protocol'] = encoder.fit_transform(data['Protocol'])
data.head()
# Out:
#       dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  flows  \
# 0  11425       1     45304   48294064  100  716000000  1.010000e+11      3
# 1  11605       1    126395  134737070  280  734000000  2.810000e+11      2
# 2  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 3  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 4  11425       1     90333   96294978  200  744000000  2.010000e+11      3
#
#    packetins  pktperflow  ...  pktrate  Pairflow  Protocol  port_no  \
# 0       1943       13535  ...      451         0         2        3
# 1       1943       13531  ...      451         0         2        4
# 2       1943       13534  ...      451         0         2        1
# 3       1943       13534  ...      451         0         2        2
# 4       1943       13534  ...      451         0         2        3
#
#     tx_bytes  rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0  143928631      3917        0      0.0       0.0      0
# 1       3842      3520        0      0.0       0.0      0
# 2       3795      1242        0      0.0       0.0      0
# 3       3688      1492        0      0.0       0.0      0
# 4       3413      3665        0      0.0       0.0      0
#
# [5 rows x 21 columns]

# %%
data['Protocol'].unique()
# Out:
# array([2, 1, 0])

# %%
data.isnull().sum()
# Out:
# dt               0
# switch           0
# pktcount         0
# bytecount        0
# dur              0
# dur_nsec         0
# tot_dur          0
# flows            0
# packetins        0
# pktperflow       0
# byteperflow      0
# pktrate          0
# Pairflow         0
# Protocol         0
# port_no          0
# tx_bytes         0
# rx_bytes         0
# tx_kbps          0
# rx_kbps        506
# tot_kbps       506
# label            0
# dtype: int64

# %%
#import seaborn as sns

# %%
#sns.heatmap(data.isnull())

# %%
# Gestion des valeurs manquantes
data['rx_kbps'].fillna(data['rx_kbps'].mean(), inplace=True)
data['tot_kbps'].fillna(data['tot_kbps'].mean(), inplace=True)
data.isnull().sum()
# Out:
# dt             0
# switch         0
# pktcount       0
# bytecount      0
# dur            0
# dur_nsec       0
# tot_dur        0
# flows          0
# packetins      0
# pktperflow     0
# byteperflow    0
# pktrate        0
# Pairflow       0
# Protocol       0
# port_no        0
# tx_bytes       0
# rx_bytes       0
# tx_kbps        0
# rx_kbps        0
# tot_kbps       0
# label          0
# dtype: int64

# %%
data
# Out:
#            dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  \
# 0       11425       1     45304   48294064  100  716000000  1.010000e+11
# 1       11605       1    126395  134737070  280  734000000  2.810000e+11
# 2       11425       1     90333   96294978  200  744000000  2.010000e+11
# 3       11425       1     90333   96294978  200  744000000  2.010000e+11
# 4       11425       1     90333   96294978  200  744000000  2.010000e+11
# ...       ...     ...       ...        ...  ...        ...           ...
# 104340   5262       3        79       7742   81  842000000  8.184200e+10
# 104341   5262       3        79       7742   81  842000000  8.184200e+10
# 104342   5262       3        31       3038   31  805000000  3.180500e+10
# 104343   5262       3        31       3038   31  805000000  3.180500e+10
# 104344   5262       3        31       3038   31  805000000  3.180500e+10
#
#         flows  packetins  pktperflow  ...  pktrate  Pairflow  Protocol  \
# 0           3       1943       13535  ...      451         0         2
# 1           2       1943       13531  ...      451         0         2
# 2           3       1943       13534  ...      451         0         2
# 3           3       1943       13534  ...      451         0         2
# 4           3       1943       13534  ...      451         0         2
# ...       ...        ...         ...  ...      ...       ...       ...
# 104340      5         10          29  ...        0         0         0
# 104341      5         10          29  ...        0         0         0
# 104342      5         10          30  ...        1         0         0
# 104343      5         10          30  ...        1         0         0
# 104344      5         10          30  ...        1         0         0
#
#         port_no   tx_bytes  rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0             3  143928631      3917        0      0.0       0.0      0
# 1             4       3842      3520        0      0.0       0.0      0
# 2             1       3795      1242        0      0.0       0.0      0
# 3             2       3688      1492        0      0.0       0.0      0
# 4             3       3413      3665        0      0.0       0.0      0
# ...         ...        ...       ...      ...      ...       ...    ...
# 104340        1      15209     12720        1      1.0       2.0      0
# 104341        3      15099     14693        1      1.0       2.0      0
# 104342        2       3409      3731        0      0.0       0.0      0
# 104343        1      15209     12720        1      1.0       2.0      0
# 104344        3      15099     14693        1      1.0       2.0      0
#
# [104345 rows x 21 columns]

# %% [markdown]
# # Étape 5 : Diviser les données : Train et Test (Normaliser les données)

# %%
data.columns
# Out:
# Index(['dt', 'switch', 'pktcount', 'bytecount', 'dur', 'dur_nsec', 'tot_dur',
#        'flows', 'packetins', 'pktperflow', 'byteperflow', 'pktrate',
#        'Pairflow', 'Protocol', 'port_no', 'tx_bytes', 'rx_bytes', 'tx_kbps',
#        'rx_kbps', 'tot_kbps', 'label'],
#       dtype='object')

# %%
#Étape 5 : Diviser les données : Train et Test (Normaliser les données)
#X = data.drop(columns='label', inplace=True, axis=1)
#y = data['label']
X = data.iloc[ : , :-1]
y = data.iloc[ : , -1]

# %%
X
# Out:
#            dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  \
# 0       11425       1     45304   48294064  100  716000000  1.010000e+11
# 1       11605       1    126395  134737070  280  734000000  2.810000e+11
# 2       11425       1     90333   96294978  200  744000000  2.010000e+11
# 3       11425       1     90333   96294978  200  744000000  2.010000e+11
# 4       11425       1     90333   96294978  200  744000000  2.010000e+11
# ...       ...     ...       ...        ...  ...        ...           ...
# 104340   5262       3        79       7742   81  842000000  8.184200e+10
# 104341   5262       3        79       7742   81  842000000  8.184200e+10
# 104342   5262       3        31       3038   31  805000000  3.180500e+10
# 104343   5262       3        31       3038   31  805000000  3.180500e+10
# 104344   5262       3        31       3038   31  805000000  3.180500e+10
#
#         flows  packetins  pktperflow  byteperflow  pktrate  Pairflow  \
# 0           3       1943       13535     14428310      451         0
# 1           2       1943       13531     14424046      451         0
# 2           3       1943       13534     14427244      451         0
# 3           3       1943       13534     14427244      451         0
# 4           3       1943       13534     14427244      451         0
# ...       ...        ...         ...          ...      ...       ...
# 104340      5         10          29         2842        0         0
# 104341      5         10          29         2842        0         0
# 104342      5         10          30         2940        1         0
# 104343      5         10          30         2940        1         0
# 104344      5         10          30         2940        1         0
#
#         Protocol  port_no   tx_bytes  rx_bytes  tx_kbps  rx_kbps  tot_kbps
# 0              2        3  143928631      3917        0      0.0       0.0
# 1              2        4       3842      3520        0      0.0       0.0
# 2              2        1       3795      1242        0      0.0       0.0
# 3              2        2       3688      1492        0      0.0       0.0
# 4              2        3       3413      3665        0      0.0       0.0
# ...          ...      ...        ...       ...      ...      ...       ...
# 104340         0        1      15209     12720        1      1.0       2.0
# 104341         0        3      15099     14693        1      1.0       2.0
# 104342         0        2       3409      3731        0      0.0       0.0
# 104343         0        1      15209     12720        1      1.0       2.0
# 104344         0        3      15099     14693        1      1.0       2.0
#
# [104345 rows x 20 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 104340    0
# 104341    0
# 104342    0
# 104343    0
# 104344    0
# Name: label, Length: 104345, dtype: int64

# %%
# Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.23, random_state=40)

# %%
print("X-train:", X_train.shape)
print("X-test:", X_test.shape)
print("y-train:", y_train.shape)
print("y-train:", y_test.shape)
# Out:
# X-train: (80345, 20)
# X-test: (24000, 20)
# y-train: (80345,)
# y-train: (24000,)

# %%
X_train
# Out:
#            dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  \
# 10499   11395       4     69567   72488814  220  746000000  2.210000e+11
# 31334    3309       6     93278   99434348  207  245000000  2.070000e+11
# 101105   6792      10       118      11564  121  447000000  1.210000e+11
# 3267     9876       2     64567   68828422  143  113000000  1.430000e+11
# 62307   29262       1       253      24794  260   81000000  2.600000e+11
# ...       ...     ...       ...        ...  ...        ...           ...
# 56760   33273       1       798      78204  818  585000000  8.190000e+11
# 93176   25170       7        12       1176   12  985000000  1.298500e+10
# 80037   14615       4     85836    4635144  151   19000000  1.510000e+11
# 30727    2829       6     98554  102693268  347  439000000  3.470000e+11
# 11590   12235       4    130900  139539400  290  749000000  2.910000e+11
#
#         flows  packetins  pktperflow  byteperflow  pktrate  Pairflow  \
# 10499       8       1943        9343      9735406      311         0
# 31334       4       7916       13523     14415518      450         0
# 101105      3       3443          30         2940        1         0
# 3267        3       1910       13526     14418716      450         0
# 62307       4       1057          29         2842        0         1
# ...       ...        ...         ...          ...      ...       ...
# 56760       7       2936          29         2842        0         1
# 93176       9       3021           0            0        0         1
# 80037       5       7385       17630       952020      587         1
# 30727       2       4440        9168      9553056      305         0
# 11590       2       2242       13685     14588210      456         0
#
#         Protocol  port_no   tx_bytes   rx_bytes  tx_kbps  rx_kbps  tot_kbps
# 10499          2        3       3413       3665        0      0.0       0.0
# 31334          2        4       5130  435554822        0   6437.0    6437.0
# 101105         0        2       5631       1632        0      0.0       0.0
# 3267           2        2       3582       1332        0      0.0       0.0
# 62307          0        3      30555  156001367        0   4972.0    4972.0
# ...          ...      ...        ...        ...      ...      ...       ...
# 56760          0        3  135645374     185738        2      2.0       4.0
# 93176          0        3  135554738  135206780        1      1.0       2.0
# 80037          1        3  150569319    8893180     3958    301.0    4259.0
# 30727          2        4       4449  245260547        0   2529.0    2529.0
# 11590          2        4       4355  143928985        0      0.0       0.0
#
# [80345 rows x 20 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 104340    0
# 104341    0
# 104342    0
# 104343    0
# 104344    0
# Name: label, Length: 104345, dtype: int64

# %%
# Standardiser les features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#X_train

# %% [markdown]
# # Étape 6 : Construire le Shallow Neural Network

# %%
# Étape 6 : Construire le Shallow Neural Network

# %%
# Creation du model
model = Sequential()

# %%
# Ajout de la couche d'entree == couche cachee
model.add(Dense(10, input_shape=(20,), activation='relu'))
#model.add(Dense(16, input_shape=(9,), activation='relu'))
#model.add(Dense(32, activation='relu'))

# Ajout de la couche de sortie
model.add(Dense(1, activation='sigmoid'))

# Compiler le modele
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Affichage de l'architecture ou la structure du model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 221 (884.00 B)
#  Trainable params: 221 (884.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Entrainement du modele
history = model.fit(X_train, y_train, epochs=150, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - accuracy: 0.7951 - loss: 0.4340 - val_accuracy: 0.9417 - val_loss: 0.1699
# Epoch 2/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9464 - loss: 0.1531 - val_accuracy: 0.9530 - val_loss: 0.1285
# Epoch 3/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9536 - loss: 0.1200 - val_accuracy: 0.9542 - val_loss: 0.1149
# Epoch 4/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9589 - loss: 0.1062 - val_accuracy: 0.9558 - val_loss: 0.1058
# Epoch 5/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9596 - loss: 0.0999 - val_accuracy: 0.9597 - val_loss: 0.0980
# Epoch 6/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9625 - loss: 0.0934 - val_accuracy: 0.9628 - val_loss: 0.0913
# Epoch 7/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9665 - loss: 0.0848 - val_accuracy: 0.9671 - val_loss: 0.0856
# Epoch 8/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9696 - loss: 0.0809 - val_accuracy: 0.9703 - val_loss: 0.0814
# Epoch 9/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9709 - loss: 0.0782 - val_accuracy: 0.9717 - val_loss: 0.0779
# Epoch 10/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9743 - loss: 0.0740 - val_accuracy: 0.9725 - val_loss: 0.0748
# Epoch 11/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9737 - loss: 0.0729 - val_accuracy: 0.9730 - val_loss: 0.0718
# Epoch 12/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9754 - loss: 0.0683 - val_accuracy: 0.9746 - val_loss: 0.0699
# Epoch 13/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9769 - loss: 0.0658 - val_accuracy: 0.9746 - val_loss: 0.0686
# Epoch 14/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9773 - loss: 0.0649 - val_accuracy: 0.9766 - val_loss: 0.0650
# Epoch 15/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9781 - loss: 0.0618 - val_accuracy: 0.9762 - val_loss: 0.0627
# Epoch 16/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9785 - loss: 0.0598 - val_accuracy: 0.9769 - val_loss: 0.0609
# Epoch 17/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9787 - loss: 0.0599 - val_accuracy: 0.9790 - val_loss: 0.0590
# Epoch 18/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9795 - loss: 0.0562 - val_accuracy: 0.9778 - val_loss: 0.0589
# Epoch 19/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9798 - loss: 0.0554 - val_accuracy: 0.9791 - val_loss: 0.0570
# Epoch 20/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9802 - loss: 0.0549 - val_accuracy: 0.9792 - val_loss: 0.0555
# Epoch 21/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9814 - loss: 0.0518 - val_accuracy: 0.9795 - val_loss: 0.0543
# Epoch 22/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9816 - loss: 0.0516 - val_accuracy: 0.9789 - val_loss: 0.0538
# Epoch 23/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9815 - loss: 0.0505 - val_accuracy: 0.9811 - val_loss: 0.0518
# Epoch 24/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.
150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9915 - loss: 0.0218 - val_accuracy: 0.9914 - val_loss: 0.0232
# Epoch 148/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9915 - loss: 0.0212 - val_accuracy: 0.9907 - val_loss: 0.0227
# Epoch 149/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9919 - loss: 0.0205 - val_accuracy: 0.9914 - val_loss: 0.0221
# Epoch 150/150
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9916 - loss: 0.0211 - val_accuracy: 0.9903 - val_loss: 0.0228

# %% [markdown]
# # Étape 7 : Visualiser l’évolution de l’entrainement du réseau de neurone

# %%
history

# %%
epoch_accuracy = history.history['accuracy']
epoch_loss = history.history['loss']

epoch_val_accuracy = history.history['val_accuracy']
epoch_val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(15, 6))
plt.plot(range(0, len(epoch_accuracy)), epoch_accuracy, color='blue', label='Training Accuracy')
plt.plot(range(0, len(epoch_loss)), epoch_loss, color='red', label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Valeur')
plt.title('Accuracy Vs Loss')
plt.legend()
plt.plot()
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.plot(range(0, len(epoch_accuracy)), epoch_accuracy, color='blue', label='Training Accuracy')
plt.plot(range(0, len(epoch_val_accuracy)), epoch_val_accuracy, color='red', label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy Vs Test Accuracy')
plt.legend()
plt.plot()
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.plot(range(0, len(epoch_loss)), epoch_loss, color='blue', label='Training Loss')
plt.plot(range(0, len(epoch_val_loss)), epoch_val_loss, color='red', label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss Vs Test Loss')
plt.legend()
plt.plot()
plt.show()

# %% [markdown]
# # Étape 8 : Evaluer le modèle

# %%
# Étape 8 : Evaluer le modèle
model.evaluate(X_test, y_test)
# Out:
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9914 - loss: 0.0204
# [0.022768869996070862, 0.9903333187103271]

# %% [markdown]
# # Deep learning Model

# %%
print(X.shape)
# Out:
# (104345, 20)

# %%
X_train,X_val,y_train,y_val = train_test_split(X,y, test_size=0.9, random_state=42)
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
print("X-train :", X_train.shape)
print("X-val :", X_val.shape)
print("X-test :", X_test.shape)
# Out:
# X-train : (73041, 20)
# X-val : (93911, 20)
# X-test : (31304, 20)

# %%
print("y-train :", X_train.shape)
print("y-val :", X_val.shape)
print("y-test :", X_test.shape)
# Out:
# y-train : (73041, 20)
# y-val : (93911, 20)
# y-test : (31304, 20)

# %%
model_dnn = Sequential()

# %%
opt = 'Adam'
epo = 5

# %%
# 1 ere couche 
model_dnn.add(Dense(15, input_shape=(20,), activation='relu'))
# La 2eme couche 
model_dnn.add(Dense(30, activation='relu'))
model_dnn.add(Dense(60,  activation='relu'))
model_dnn.add(Dense(120, activation='relu'))
model_dnn.add(Dense(240, activation='relu'))

# la couche de sortie
model_dnn.add(Dense(1, activation='sigmoid'))   
#compiler le modele
model_dnn.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
model_dnn.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                │ (None, 15)             │           315 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 30)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 60)             │         1,860 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 120)            │         7,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 240)            │        29,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 1)              │           241 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 39,256 (153.34 KB)
#  Trainable params: 39,256 (153.34 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# entrainement du model 
history = model.fit(X_train, y_train, epochs=epo, verbose=1, validation_data=(X_val, y_val))
# Out:
# Epoch 1/5
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.5864 - loss: 1139539200.0000 - val_accuracy: 0.6158 - val_loss: 1850828032.0000
# Epoch 2/5
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.5946 - loss: 940497408.0000 - val_accuracy: 0.4151 - val_loss: 1093163904.0000
# Epoch 3/5
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.5938 - loss: 914412224.0000 - val_accuracy: 0.4176 - val_loss: 511074688.0000
# Epoch 4/5
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.5987 - loss: 810145920.0000 - val_accuracy: 0.6581 - val_loss: 388495904.0000
# Epoch 5/5
# 2283/2283 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.6006 - loss: 927801792.0000 - val_accuracy: 0.6435 - val_loss: 1083620608.0000
